# %%
import copy
import gymnasium as gym
import numpy as np
from datetime import datetime, timedelta

# %%
class Config():
    def __init__(self):
        self.env_name = "CartPole-v1"
        self.total_episode = 100000
        self.gamma = 0.99
        self.num_action = 2
        self.n_bins = 10
        self.epsilon=1.0
        self.decay_step=int(0.5 * self.total_episode)
        self.eps_min=0.05
        self.lr = 0.1
        self.test_frequency = 10

config = Config()

# %%
import numpy as np

class Discretizer:
    def __init__(self, n_bins=6):
        self.n_bins = n_bins
        self.cart_pos_bins = np.linspace(-4.8, 4.8, n_bins - 1)
        self.cart_vel_bins = np.linspace(-3.0, 3.0, n_bins - 1)  
        self.pole_angle_bins = np.linspace(-0.419, 0.419, n_bins - 1)
        self.pole_vel_bins = np.linspace(-3.0, 3.0, n_bins - 1) 

    def discretize(self, state):
        cart_pos, cart_vel, pole_angle, pole_vel = state

        d_cart_pos = np.digitize(cart_pos, self.cart_pos_bins)
        d_cart_vel = np.digitize(cart_vel, self.cart_vel_bins)
        d_pole_angle = np.digitize(pole_angle, self.pole_angle_bins)
        d_pole_vel = np.digitize(pole_vel, self.pole_vel_bins)

        return (d_cart_pos, d_cart_vel, d_pole_angle, d_pole_vel)

    def get_state_index(self, discrete_state):
        d = discrete_state
        return ((d[0] * self.n_bins + d[1]) * self.n_bins + d[2]) * self.n_bins + d[3]

# %%
def select_action(Q_TableA, Q_TableB, state, epsilon):
    if np.random.rand() < epsilon:
        return np.random.randint(Q_TableA.shape[1])
    else:
        return np.argmax(Q_TableA[state] + Q_TableB[state])

# %%
def decay_epsilon(epsilon, decay_per_step):
    epsilon = max(epsilon - decay_per_step, config.eps_min)
    return epsilon

# %%
def UpdateQ(Q_Table1, Q_Table2, state, action, next_state, reward, done):
    if not done:
        next_action = np.argmax(Q_Table1[next_state])
        target = Q_Table2[next_state, next_action] * config.gamma + reward
    else:
        next_action = -1
        target = reward
    q_sa = Q_Table1[state, action]
    Q_Table1[state, action] += config.lr * (target - q_sa)

# %%
def test(config, Q_TableA, Q_TableB, discretizer):
    env = gym.make(config.env_name)
    state, _ = env.reset()
    state = discretizer.get_state_index(discretizer.discretize(state))
    done = False
    episode_reward = 0.

    while not done:
        action = np.argmax(Q_TableA[state] + Q_TableB[state])
        next_state, reward, terminated, truncated, info = env.step(action)
        next_state = discretizer.get_state_index(discretizer.discretize(next_state))
        episode_reward += reward
        done = terminated or truncated
        state = next_state
    return episode_reward

# %%
discretizer = Discretizer(config.n_bins)
Q_TableA = np.zeros((config.n_bins**4, config.num_action))
Q_TableB = np.zeros((config.n_bins**4, config.num_action))
episode_rewards = []
test_episode_rewards = []
epsilon = config.epsilon
decay_per_step = (epsilon - config.eps_min) / config.decay_step
max_test_reward = 0.

for episode in range(1, config.total_episode+1):
    env = gym.make(config.env_name)
    state, _ = env.reset()
    state = discretizer.get_state_index(discretizer.discretize(state))
    done = False

    episode_reward = 0.

    while not done:
        action = select_action(Q_TableA, Q_TableB, state, epsilon)
        next_state, reward, terminated, truncated, info = env.step(action)
        next_state = discretizer.get_state_index(discretizer.discretize(next_state))
        episode_reward += reward
        done = terminated or truncated
        if np.random.rand() < 0.5:
            UpdateQ(Q_TableA, Q_TableB, state, action, next_state, reward, done)
        else:
            UpdateQ(Q_TableB, Q_TableA, state, action, next_state, reward, done)
        state = next_state
    
    episode_rewards.append(episode_reward)
    epsilon = decay_epsilon(epsilon, decay_per_step)
    
    if episode % 1000 == 0:
        print(f"Episode: {episode} Rewards: {episode_reward} Mean_Rewards: {np.array(episode_rewards[-min(100, len(episode_rewards)):]).mean():.4f} Epsilon: {epsilon:.4f}")

    if episode % config.test_frequency == 0:
        test_episode_reward = test(config, Q_TableA, Q_TableB, discretizer)
        test_episode_rewards.append(test_episode_reward)
        max_test_reward = max(max_test_reward, test_episode_reward)
        if len(test_episode_rewards) % 1000 == 0:
            print(f"Test Episode {len(test_episode_rewards)}: Rewards: {test_episode_reward} \
Mean_Rewards: {np.array(test_episode_rewards[-min(100, len(test_episode_rewards)):]).mean():.4f} Max_Rewards: {max_test_reward}")
# Out:
# Episode: 1000 Rewards: 61.0 Mean_Rewards: 21.8800 Epsilon: 0.9810
# Episode: 2000 Rewards: 13.0 Mean_Rewards: 24.5300 Epsilon: 0.9620
# Episode: 3000 Rewards: 39.0 Mean_Rewards: 25.2100 Epsilon: 0.9430
# Episode: 4000 Rewards: 27.0 Mean_Rewards: 25.3600 Epsilon: 0.9240
# Episode: 5000 Rewards: 28.0 Mean_Rewards: 22.7900 Epsilon: 0.9050
# Episode: 6000 Rewards: 17.0 Mean_Rewards: 30.4300 Epsilon: 0.8860
# Episode: 7000 Rewards: 18.0 Mean_Rewards: 26.5100 Epsilon: 0.8670
# Episode: 8000 Rewards: 23.0 Mean_Rewards: 29.3000 Epsilon: 0.8480
# Episode: 9000 Rewards: 19.0 Mean_Rewards: 32.6900 Epsilon: 0.8290
# Episode: 10000 Rewards: 37.0 Mean_Rewards: 34.7700 Epsilon: 0.8100
# Test Episode 1000: Rewards: 184.0 Mean_Rewards: 178.7400 Max_Rewards: 500.0
# Episode: 11000 Rewards: 20.0 Mean_Rewards: 36.5100 Epsilon: 0.7910
# Episode: 12000 Rewards: 27.0 Mean_Rewards: 36.5600 Epsilon: 0.7720
# Episode: 13000 Rewards: 13.0 Mean_Rewards: 40.6700 Epsilon: 0.7530
# Episode: 14000 Rewards: 17.0 Mean_Rewards: 41.3200 Epsilon: 0.7340
# Episode: 15000 Rewards: 18.0 Mean_Rewards: 47.7000 Epsilon: 0.7150
# Episode: 16000 Rewards: 12.0 Mean_Rewards: 46.9100 Epsilon: 0.6960
# Episode: 17000 Rewards: 141.0 Mean_Rewards: 54.1200 Epsilon: 0.6770
# Episode: 18000 Rewards: 30.0 Mean_Rewards: 49.2600 Epsilon: 0.6580
# Episode: 19000 Rewards: 75.0 Mean_Rewards: 53.8700 Epsilon: 0.6390
# Episode: 20000 Rewards: 38.0 Mean_Rewards: 60.9200 Epsilon: 0.6200
# Test Episode 2000: Rewards: 219.0 Mean_Rewards: 232.6000 Max_Rewards: 500.0
# Episode: 21000 Rewards: 56.0 Mean_Rewards: 62.4700 Epsilon: 0.6010
# Episode: 22000 Rewards: 43.0 Mean_Rewards: 77.6300 Epsilon: 0.5820
# Episode: 23000 Rewards: 11.0 Mean_Rewards: 63.6300 Epsilon: 0.5630
# Episode: 24000 Rewards: 43.0 Mean_Rewards: 84.2000 Epsilon: 0.5440
# Episode: 25000 Rewards: 146.0 Mean_Rewards: 104.5700 Epsilon: 0.5250
# Episode: 26000 Rewards: 112.0 Mean_Rewards: 101.3200 Epsilon: 0.5060
# Episode: 27000 Rewards: 140.0 Mean_Rewards: 80.1400 Epsilon: 0.4870
# Episode: 28000 Rewards: 74.0 Mean_Rewards: 100.6400 Epsilon: 0.4680
# Episode: 29000 Rewards: 65.0 Mean_Rewards: 116.2000 Epsilon: 0.4490
# Episode: 30000 Rewards: 97.0 Mean_Rewards: 106.8300 Epsilon: 0.4300
# Test Episode 3000: Rewards: 140.0 Mean_Rewards: 291.9200 Max_Rewards: 500.0
# Episode: 31000 Rewards: 78.0 Mean_Rewards: 123.1800 Epsilon: 0.4110
# Episode: 32000 Rewards: 23.0 Mean_Rewards: 127.8900 Epsilon: 0.3920
# Episode: 33000 Rewards: 161.0 Mean_Rewards: 151.2300 Epsilon: 0.3730
# Episode: 34000 Rewards: 35.0 Mean_Rewards: 150.4100 Epsilon: 0.3540
# Episode: 35000 Rewards: 61.0 Mean_Rewards: 146.7700 Epsilon: 0.3350
# Episode: 36000 Rewards: 60.0 Mean_Rewards: 175.0900 Epsilon: 0.3160
# Episode: 37000 Rewards: 125.0 Mean_Rewards: 182.7100 Epsilon: 0.2970
# Episode: 38000 Rewards: 167.0 Mean_Rewards: 170.7300 Epsilon: 0.2780
# Episode: 39000 Rewards: 55.0 Mean_Rewards: 210.0700 Epsilon: 0.2590
# Episode: 40000 Rewards: 190.0 Mean_Rewards: 161.8400 Epsilon: 0.2400
# Test Episode 4000: Rewards: 500.0 Mean_Rewards: 267.9900 Max_Rewards: 500.0
# Episode: 41000 Rewards: 189.0 Mean_Rewards: 157.8000 Epsilon: 0.2210
# Episode: 42000 Rewards: 72.0 Mean_Rewards: 187.4800 Epsilon: 0.2020
# Episode: 43000 Rewards: 191.0 Mean_Rewards: 171.7500 Epsilon: 0.1830
# Episode: 44000 Rewards: 259.0 Mean_Rewards: 237.9300 Epsilon: 0.1640
# Episode: 45000 Rewards: 24.0 Mean_Rewards: 272.3900 Epsilon: 0.1450
# Episode: 46000 Rewards: 500.0 Mean_Rewards: 288.2600 Epsilon: 0.1260
# Episode: 47000 Rewards: 500.0 Mean_Rewards: 318.5500 Epsilon: 0.1070
# Episode: 48000 Rewards: 170.0 Mean_Rewards: 275.0900 Epsilon: 0.0880
# Episode: 49000 Rewards: 231.0 Mean_Rewards: 153.2900 Epsilon: 0.0690
# Episode: 50000 Rewards: 455.0 Mean_Rewards: 283.3800 Epsilon: 0.0500
# Test Episode 5000: Rewards: 43.0 Mean_Rewards: 326.5100 Max_Rewards: 500.0
# Episode: 51000 Rewards: 170.0 Mean_Rewards: 220.6100 Epsilon: 0.0500
# Episode: 52000 Rewards: 420.0 Mean_Rewards: 359.3100 Epsilon: 0.0500
# Episode: 53000 Rewards: 356.0 Mean_Rewards: 278.3700 Epsilon: 0.0500
# Episode: 54000 Rewards: 500.0 Mean_Rewards: 352.7800 Epsilon: 0.0500
# Episode: 55000 Rewards: 477.0 Mean_Rewards: 215.3200 Epsilon: 0.0500
# Episode: 56000 Rewards: 500.0 Mean_Rewards: 272.5800 Epsilon: 0.0500
# Episode: 57000 Rewards: 49.0 Mean_Rewards: 265.5300 Epsilon: 0.0500
# Episode: 58000 Rewards: 121.0 Mean_Rewards: 318.4000 Epsilon: 0.0500
# Episode: 59000 Rewards: 163.0 Mean_Rewards: 206.2100 Epsilon: 0.0500
# Episode: 60000 Rewards: 236.0 Mean_Rewards: 287.3900 Epsilon: 0.0500
# Test Episode 6000: Rewards: 18.0 Mean_Rewards: 315.5900 Max_Rewards: 500.0
# Episode: 61000 Rewards: 500.0 Mean_Rewards: 343.2000 Epsilon: 0.0500
# Episode: 62000 Rewards: 170.0 Mean_Rewards: 284.7200 Epsilon: 0.0500
# Episode: 63000 Rewards: 64.0 Mean_Rewards: 264.1100 Epsilon: 0.0500
# Episode: 64000 Rewards: 109.0 Mean_Rewards: 196.4200 Epsilon: 0.0500
# Episode: 65000 Rewards: 112.0 Mean_Rewards: 212.9800 Epsilon: 0.0500
# Episode: 66000 Rewards: 305.0 Mean_Rewards: 208.1600 Epsilon: 0.0500
# Episode: 67000 Rewards: 118.0 Mean_Rewards: 171.0600 Epsilon: 0.0500
# Episode: 68000 Rewards: 153.0 Mean_Rewards: 267.5700 Epsilon: 0.0500
# Episode: 69000 Rewards: 187.0 Mean_Rewards: 258.9800 Epsilon: 0.0500
# Episode: 70000 Rewards: 269.0 Mean_Rewards: 202.8000 Epsilon: 0.0500
# Test Episode 7000: Rewards: 315.0 Mean_Rewards: 220.1000 Max_Rewards: 500.0
# Episode: 71000 Rewards: 112.0 Mean_Rewards: 218.4600 Epsilon: 0.0500
# Episode: 72000 Rewards: 118.0 Mean_Rewards: 233.0300 Epsilon: 0.0500
# Episode: 73000 Rewards: 500.0 Mean_Rewards: 241.9600 Epsilon: 0.0500
# Episode: 74000 Rewards: 209.0 Mean_Rewards: 310.2700 Epsilon: 0.0500
# Episode: 75000 Rewards: 495.0 Mean_Rewards: 274.7500 Epsilon: 0.0500
# Episode: 76000 Rewards: 500.0 Mean_Rewards: 234.6400 Epsilon: 0.0500
# Episode: 77000 Rewards: 390.0 Mean_Rewards: 345.2400 Epsilon: 0.0500
# Episode: 78000 Rewards: 13.0 Mean_Rewards: 230.8600 Epsilon: 0.0500
# Episode: 79000 Rewards: 295.0 Mean_Rewards: 346.0300 Epsilon: 0.0500
# Episode: 80000 Rewards: 138.0 Mean_Rewards: 216.4300 Epsilon: 0.0500
# Test Episode 8000: Rewards: 137.0 Mean_Rewards: 279.5400 Max_Rewards: 500.0
# Episode: 81000 Rewards: 288.0 Mean_Rewards: 303.4800 Epsilon: 0.0500
# Episode: 82000 Rewards: 500.0 Mean_Rewards: 375.3500 Epsilon: 0.0500
# Episode: 83000 Rewards: 283.0 Mean_Rewards: 177.6900 Epsilon: 0.0500
# Episode: 84000 Rewards: 155.0 Mean_Rewards: 202.6300 Epsilon: 0.0500
# Episode: 85000 Rewards: 395.0 Mean_Rewards: 385.3800 Epsilon: 0.0500
# Episode: 86000 Rewards: 170.0 Mean_Rewards: 303.7800 Epsilon: 0.0500
# Episode: 87000 Rewards: 132.0 Mean_Rewards: 150.9800 Epsilon: 0.0500
# Episode: 88000 Rewards: 469.0 Mean_Rewards: 349.1200 Epsilon: 0.0500
# Episode: 89000 Rewards: 500.0 Mean_Rewards: 284.4300 Epsilon: 0.0500
# Episode: 90000 Rewards: 307.0 Mean_Rewards: 362.1000 Epsilon: 0.0500
# Test Episode 9000: Rewards: 428.0 Mean_Rewards: 310.9700 Max_Rewards: 500.0
# Episode: 91000 Rewards: 435.0 Mean_Rewards: 414.8100 Epsilon: 0.0500
# Episode: 92000 Rewards: 316.0 Mean_Rewards: 256.8500 Epsilon: 0.0500
# Episode: 93000 Rewards: 330.0 Mean_Rewards: 274.6500 Epsilon: 0.0500
# Episode: 94000 Rewards: 190.0 Mean_Rewards: 286.1300 Epsilon: 0.0500
# Episode: 95000 Rewards: 500.0 Mean_Rewards: 408.6900 Epsilon: 0.0500
# Episode: 96000 Rewards: 280.0 Mean_Rewards: 280.1600 Epsilon: 0.0500
# Episode: 97000 Rewards: 500.0 Mean_Rewards: 297.1300 Epsilon: 0.0500
# Episode: 98000 Rewards: 63.0 Mean_Rewards: 106.9000 Epsilon: 0.0500
# Episode: 99000 Rewards: 130.0 Mean_Rewards: 203.6300 Epsilon: 0.0500
# Episode: 100000 Rewards: 44.0 Mean_Rewards: 181.8400 Epsilon: 0.0500
# Test Episode 10000: Rewards: 194.0 Mean_Rewards: 271.2700 Max_Rewards: 500.0

# %%
idx_full_rewards = np.array(test_episode_rewards) == 500
print(idx_full_rewards.sum() / len(test_episode_rewards))
# Out:
# 0.1429

# %%
import matplotlib.pyplot as plt

train_episodes = list(range(1, len(episode_rewards)+1))
test_episodes = list(range(10, len(episode_rewards)+1, 10))  # test sau mỗi 10 train episodes (0-based index)

mean_rewards = []
mean_test_rewards = []
for i in range(len(episode_rewards)):
    mean_rewards.append(np.array(episode_rewards)[max(0, i-100):i+1].mean())
for i in range(len(test_episode_rewards)):
    mean_test_rewards.append(np.array(test_episode_rewards)[max(0, i-100):i+1].mean())

plt.figure(figsize=(10, 6))

idx_full_rewards = np.array(test_episode_rewards) == 500

plt.plot(train_episodes, mean_rewards, label='Train Rewards [Last 100]', alpha=0.5)
plt.plot(test_episodes, mean_test_rewards, label='Test Rewards [Last 100]', linewidth=2)
plt.scatter(np.array(test_episodes)[idx_full_rewards], 
            np.array(test_episode_rewards)[idx_full_rewards], label='Test Rewards = 500', alpha=0.6, s=20, color = 'green')

plt.xlabel("Episode")
plt.ylabel("Reward")
plt.title("Train vs Test Rewards")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 6))

plt.plot(train_episodes, mean_rewards, label='Train Rewards [Last 100]', alpha=0.5)
plt.plot(test_episodes, mean_test_rewards, label='Test Rewards [Last 100]', linewidth=2)

plt.xlabel("Episode")
plt.ylabel("Reward")
plt.title("Train vs Test Rewards")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
