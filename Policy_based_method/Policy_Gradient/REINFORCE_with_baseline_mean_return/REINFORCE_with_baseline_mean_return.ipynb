# %%
import gymnasium as gym
import numpy as np
from datetime import datetime, timedelta
import torch
import torch.nn as nn
import torch.nn.functional as F

# %%
class Config():
    def __init__(self):
        # env
        self.env_name = "CartPole-v1"
        self.gamma = 0.99
        self.num_action = 2
        self.state_dim = 4

        # training
        self.total_episodes = 5000
        self.learning_rate = 2.3e-3
        self.weight_decay = 1e-4
        self.test_frequency = 10
        self.num_test_episodes = 10
        self.save_frequency = 1000
        self.save_path = 'best_model.pth'
        self.device = "cuda" if torch.cuda.is_available() else "cpu"

config = Config()

# %%
class Actor(nn.Module):
    def __init__(self, state_dim=4, num_action=2):
        super(Actor, self).__init__()
        self.fc1 = nn.Linear(state_dim, 64)
        self.fc2 = nn.Linear(64, 64)
        self.policy = nn.Linear(64, num_action)

    def forward(self, state):
        x = F.relu(self.fc1(state))
        x = F.relu(self.fc2(x))
        logits = self.policy(x)
        return logits

# %%
class Agent():
    def __init__(self, actor_model, env, device, learning_rate, weight_decay, total_episodes, 
                 gamma, test_frequency, save_frequency, num_test_episodes, save_path):
        self.actor_model = actor_model
        self.actor_optimizer = torch.optim.Adam(self.actor_model.parameters(), lr=learning_rate, weight_decay=weight_decay)

        self.env = env
        self.gamma = gamma

        self.total_episodes = total_episodes
        self.test_frequency = test_frequency
        self.save_frequency = save_frequency
        self.num_test_episodes = num_test_episodes
        self.device = device
        config.save_path = save_path

    def sample_action(self, state, is_testing = False):
        with torch.no_grad():
            state = torch.tensor(np.array(state), device = self.device).unsqueeze(0)
            logits = self.actor_model(state)
            if is_testing:
                action = logits[0].argmax(-1).item()
            else:
                probs = torch.softmax(logits, -1)
                distribution = torch.distributions.Categorical(probs)
                action = distribution.sample().cpu().numpy()[0]
        return action

    def play_episode(self, is_testing = False):
        done = False
        state, info = self.env.reset()
        episode_reward = 0.
        states = []
        actions = []
        rewards = []
        while not done:
            action = self.sample_action(state, is_testing)
            next_state, reward, terminated, truncated, info = self.env.step(action)
            episode_reward += reward
            states.append(state)
            actions.append(action)
            rewards.append(reward)
            done = terminated or truncated
            state = next_state
        return episode_reward, states, actions, rewards
    
    def compute_return(self, rewards):
        G = 0
        returns = []
        for reward in rewards[::-1]:
            G = G * self.gamma + reward
            returns.append(G)
        return returns[::-1]
    
    def train(self, states, actions, returns):
        states = torch.tensor(np.array(states), device = self.device)
        returns = torch.tensor(np.array(returns), device = self.device).float()

        self.actor_optimizer.zero_grad()

        logits = self.actor_model(states)
        probs = torch.softmax(logits, -1)

        index = torch.arange(0, len(returns), device = self.device)
        actions = torch.tensor(np.array(actions), device = self.device, dtype = torch.int64)

        baseline = returns.mean()

        loss = -((probs[index, actions] + 1e-9).log() * (returns - baseline)).mean()

        loss.backward()
        self.actor_optimizer.step()

        return loss.item()

    def learn(self):
        self.episode_rewards = []
        self.test_episode_rewards = []
        self.losses = []
        max_test_rewards = 0.

        for episode in range(1, self.total_episodes+1):
            start_time = datetime.now()
            episode_reward, states, actions, rewards = self.play_episode()
            returns = self.compute_return(rewards)
            loss = self.train(states, actions, returns)
            self.episode_rewards.append(episode_reward)
            self.losses.append(loss)
            if len(self.losses) > 100:
                self.losses.pop(0)

            if episode % 100 == 0:
                print(f"Episode: {episode}, Reward: {episode_reward}, Mean Reward [Last 100]: {np.array(self.episode_rewards)[-min(100, episode):].mean():.4f}, "
                      f"Max Reward: {max(self.episode_rewards)}, Loss: {np.array(self.losses).mean():.4f}, "
                      f"Episode Time: {datetime.now() - start_time}")
                
            if episode % self.test_frequency == 0:
                start_time = datetime.now()
                for _ in range(1, self.num_test_episodes+1):
                    test_episode_reward, _, _, _ = self.play_episode(is_testing=True)
                    self.test_episode_rewards.append(test_episode_reward)
                mean_test_rewards = np.array(self.test_episode_rewards[-self.test_frequency:]).mean()
                if mean_test_rewards > max_test_rewards:
                    max_test_rewards = mean_test_rewards
                    torch.save(self.actor_model.state_dict(), config.save_path)
                if len(self.test_episode_rewards) % 100 == 0:
                    print(f"Test Episode: {len(self.test_episode_rewards)}, Reward: {episode_reward}, "
                        f"Mean Reward [Last {self.num_test_episodes}]: {np.array(self.test_episode_rewards)[-min(self.num_test_episodes, len(self.test_episode_rewards)):].mean():.4f}, "
                        f"Max Reward: {max_test_rewards}, Test Time: {datetime.now() - start_time}")
                
            if episode % self.save_frequency == 0:
                torch.save(self.actor_model.state_dict(), f"{episode}.pth")

# %%
actor_model = Actor(config.state_dim, config.num_action)
env = gym.make(config.env_name, render_mode="rgb_array")
agent = Agent(actor_model, env, config.device, config.learning_rate, config.weight_decay, config.total_episodes,
              config.gamma, config.test_frequency, config.save_frequency, config.num_test_episodes, config.save_path)

# %%
agent.learn()
# Out:
# Episode: 100, Reward: 55.0, Mean Reward [Last 100]: 66.1000, Max Reward: 230.0, Loss: -0.1319, Episode Time: 0:00:00.025846
# Test Episode: 100, Reward: 55.0, Mean Reward [Last 10]: 158.1000, Max Reward: 338.5, Test Time: 0:00:00.258017
# Episode: 200, Reward: 242.0, Mean Reward [Last 100]: 221.3600, Max Reward: 500.0, Loss: -0.1814, Episode Time: 0:00:00.131150
# Test Episode: 200, Reward: 242.0, Mean Reward [Last 10]: 500.0000, Max Reward: 500.0, Test Time: 0:00:00.737246
# Episode: 300, Reward: 161.0, Mean Reward [Last 100]: 362.1100, Max Reward: 500.0, Loss: -0.1793, Episode Time: 0:00:00.053166
# Test Episode: 300, Reward: 161.0, Mean Reward [Last 10]: 131.3000, Max Reward: 500.0, Test Time: 0:00:00.208836
# Episode: 400, Reward: 179.0, Mean Reward [Last 100]: 105.4800, Max Reward: 500.0, Loss: -0.4877, Episode Time: 0:00:00.073753
# Test Episode: 400, Reward: 179.0, Mean Reward [Last 10]: 193.5000, Max Reward: 500.0, Test Time: 0:00:00.364742
# Episode: 500, Reward: 168.0, Mean Reward [Last 100]: 223.5900, Max Reward: 500.0, Loss: -0.3369, Episode Time: 0:00:00.059689
# Test Episode: 500, Reward: 168.0, Mean Reward [Last 10]: 151.3000, Max Reward: 500.0, Test Time: 0:00:00.214650
# Episode: 600, Reward: 500.0, Mean Reward [Last 100]: 265.1000, Max Reward: 500.0, Loss: -0.3199, Episode Time: 0:00:00.205697
# Test Episode: 600, Reward: 500.0, Mean Reward [Last 10]: 499.1000, Max Reward: 500.0, Test Time: 0:00:00.802119
# Episode: 700, Reward: 500.0, Mean Reward [Last 100]: 471.0600, Max Reward: 500.0, Loss: -0.1445, Episode Time: 0:00:00.172219
# Test Episode: 700, Reward: 500.0, Mean Reward [Last 10]: 500.0000, Max Reward: 500.0, Test Time: 0:00:00.712262
# Episode: 800, Reward: 209.0, Mean Reward [Last 100]: 400.3000, Max Reward: 500.0, Loss: -0.2240, Episode Time: 0:00:00.086093
# Test Episode: 800, Reward: 209.0, Mean Reward [Last 10]: 215.4000, Max Reward: 500.0, Test Time: 0:00:00.332581
# Episode: 900, Reward: 173.0, Mean Reward [Last 100]: 150.5600, Max Reward: 500.0, Loss: -0.4394, Episode Time: 0:00:00.080344
# Test Episode: 900, Reward: 173.0, Mean Reward [Last 10]: 175.9000, Max Reward: 500.0, Test Time: 0:00:00.339791
# Episode: 1000, Reward: 500.0, Mean Reward [Last 100]: 343.5000, Max Reward: 500.0, Loss: -0.1829, Episode Time: 0:00:00.243418
# Test Episode: 1000, Reward: 500.0, Mean Reward [Last 10]: 500.0000, Max Reward: 500.0, Test Time: 0:00:00.896175
# Episode: 1100, Reward: 257.0, Mean Reward [Last 100]: 430.0200, Max Reward: 500.0, Loss: -0.0198, Episode Time: 0:00:00.105056
# Test Episode: 1100, Reward: 257.0, Mean Reward [Last 10]: 264.2000, Max Reward: 500.0, Test Time: 0:00:00.416250
# Episode: 1200, Reward: 417.0, Mean Reward [Last 100]: 308.6100, Max Reward: 500.0, Loss: -0.0333, Episode Time: 0:00:00.185017
# Test Episode: 1200, Reward: 417.0, Mean Reward [Last 10]: 446.8000, Max Reward: 500.0, Test Time: 0:00:00.695864
# Episode: 1300, Reward: 487.0, Mean Reward [Last 100]: 450.3300, Max Reward: 500.0, Loss: -0.0227, Episode Time: 0:00:00.209679
# Test Episode: 1300, Reward: 487.0, Mean Reward [Last 10]: 500.0000, Max Reward: 500.0, Test Time: 0:00:00.659534
# Episode: 1400, Reward: 324.0, Mean Reward [Last 100]: 407.2000, Max Reward: 500.0, Loss: -0.1326, Episode Time: 0:00:00.154586
# Test Episode: 1400, Reward: 324.0, Mean Reward [Last 10]: 318.6000, Max Reward: 500.0, Test Time: 0:00:00.530086
# Episode: 1500, Reward: 318.0, Mean Reward [Last 100]: 335.4900, Max Reward: 500.0, Loss: 0.0474, Episode Time: 0:00:00.113897
# Test Episode: 1500, Reward: 318.0, Mean Reward [Last 10]: 322.3000, Max Reward: 500.0, Test Time: 0:00:00.587653
# Episode: 1600, Reward: 288.0, Mean Reward [Last 100]: 318.8800, Max Reward: 500.0, Loss: 0.0776, Episode Time: 0:00:00.128134
# Test Episode: 1600, Reward: 288.0, Mean Reward [Last 10]: 300.8000, Max Reward: 500.0, Test Time: 0:00:00.488384
# Episode: 1700, Reward: 394.0, Mean Reward [Last 100]: 254.6000, Max Reward: 500.0, Loss: -0.1546, Episode Time: 0:00:00.142327
# Test Episode: 1700, Reward: 394.0, Mean Reward [Last 10]: 402.5000, Max Reward: 500.0, Test Time: 0:00:00.483405
# Episode: 1800, Reward: 431.0, Mean Reward [Last 100]: 464.7000, Max Reward: 500.0, Loss: 0.0165, Episode Time: 0:00:00.192858
# Test Episode: 1800, Reward: 431.0, Mean Reward [Last 10]: 480.3000, Max Reward: 500.0, Test Time: 0:00:00.736761
# Episode: 1900, Reward: 500.0, Mean Reward [Last 100]: 482.4400, Max Reward: 500.0, Loss: -0.0114, Episode Time: 0:00:00.191740
# Test Episode: 1900, Reward: 500.0, Mean Reward [Last 10]: 500.0000, Max Reward: 500.0, Test Time: 0:00:00.768502
# Episode: 2000, Reward: 500.0, Mean Reward [Last 100]: 500.0000, Max Reward: 500.0, Loss: 0.0107, Episode Time: 0:00:00.199830
# Test Episode: 2000, Reward: 500.0, Mean Reward [Last 10]: 500.0000, Max Reward: 500.0, Test Time: 0:00:00.758678
# Episode: 2100, Reward: 500.0, Mean Reward [Last 100]: 499.7600, Max Reward: 500.0, Loss: 0.0514, Episode Time: 0:00:00.209219
# Test Episode: 2100, Reward: 500.0, Mean Reward [Last 10]: 500.0000, Max Reward: 500.0, Test Time: 0:00:00.770007
# Episode: 2200, Reward: 14.0, Mean Reward [Last 100]: 414.6800, Max Reward: 500.0, Loss: -0.1046, Episode Time: 0:00:00.009003
# Test Episode: 2200, Reward: 14.0, Mean Reward [Last 10]: 224.1000, Max Reward: 500.0, Test Time: 0:00:00.395610
# Episode: 2300, Reward: 147.0, Mean Reward [Last 100]: 109.5700, Max Reward: 500.0, Loss: -0.5030, Episode Time: 0:00:00.063345
# Test Episode: 2300, Reward: 147.0, Mean Reward [Last 10]: 157.3000, Max Reward: 500.0, Test Time: 0:00:00.282922
# Episode: 2400, Reward: 500.0, Mean Reward [Last 100]: 374.5700, Max Reward: 500.0, Loss: -0.2462, Episode Time: 0:00:00.199898
# Test Episode: 2400, Reward: 500.0, Mean Reward [Last 10]: 500.0000, Max Reward: 500.0, Test Time: 0:00:00.766873
# Episode: 2500, Reward: 500.0, Mean Reward [Last 100]: 500.0000, Max Reward: 500.0, Loss: 0.0056, Episode Time: 0:00:00.199687
# Test Episode: 2500, Reward: 500.0, Mean Reward [Last 10]: 500.0000, Max Reward: 500.0, Test Time: 0:00:00.752279
# Episode: 2600, Reward: 500.0, Mean Reward [Last 100]: 500.0000, Max Reward: 500.0, Loss: 0.1555, Episode Time: 0:00:00.205562
# Test Episode: 2600, Reward: 500.0, Mean Reward [Last 10]: 500.0000, Max Reward: 500.0, Test Time: 0:00:00.640638
# Episode: 2700, Reward: 500.0, Mean Reward [Last 100]: 500.0000, Max Reward: 500.0, Loss: -0.0012, Episode Time: 0:00:00.200004
# Test Episode: 2700, Reward: 500.0, Mean Reward [Last 10]: 500.0000, Max Reward: 500.0, Test Time: 0:00:00.595967
# Episode: 2800, Reward: 500.0, Mean Reward [Last 100]: 500.0000, Max Reward: 500.0, Loss: 0.0175, Episode Time: 0:00:00.187710
# Test Episode: 2800, Reward: 500.0, Mean Reward [Last 10]: 500.0000, Max Reward: 500.0, Test Time: 0:00:00.685018
# Episode: 2900, Reward: 500.0, Mean Reward [Last 100]: 500.0000, Max Reward: 500.0, Loss: 0.0043, Episode Time: 0:00:00.182401
# Test Episode: 2900, Reward: 500.0, Mean Reward [Last 10]: 500.0000, Max Reward: 500.0, Test Time: 0:00:00.716459
# Episode: 3000, Reward: 500.0, Mean Reward [Last 100]: 500.0000, Max Reward: 500.0, Loss: 0.0218, Episode Time: 0:00:00.224895
# Test Episode: 3000, Reward: 500.0, Mean Reward [Last 10]: 500.0000, Max Reward: 500.0, Test Time: 0:00:00.904493
# Episode: 3100, Reward: 500.0, Mean Reward [Last 100]: 500.0000, Max Reward: 500.0, Loss: -0.0492, Episode Time: 0:00:00.206742
# Test Episode: 3100, Reward: 500.0, Mean Reward [Last 10]: 500.0000, Max Reward: 500.0, Test Time: 0:00:00.891957
# Episode: 3200, Reward: 417.0, Mean Reward [Last 100]: 496.9700, Max Reward: 500.0, Loss: -0.0813, Episode Time: 0:00:00.200104
# Test Episode: 3200, Reward: 417.0, Mean Reward [Last 10]: 372.9000, Max Reward: 500.0, Test Time: 0:00:00.682028
# Episode: 3300, Reward: 500.0, Mean Reward [Last 100]: 480.2600, Max Reward: 500.0, Loss: -0.1298, Episode Time: 0:00:00.171972
# Test Episode: 3300, Reward: 500.0, Mean Reward [Last 10]: 500.0000, Max Reward: 500.0, Test Time: 0:00:00.720913
# Episode: 3400, Reward: 500.0, Mean Reward [Last 100]: 498.0300, Max Reward: 500.0, Loss: -0.1254, Episode Time: 0:00:00.166697
# Test Episode: 3400, Reward: 500.0, Mean Reward [Last 10]: 500.0000, Max Reward: 500.0, Test Time: 0:00:00.793179
# Episode: 3500, Reward: 500.0, Mean Reward [Last 100]: 500.0000, Max Reward: 500.0, Loss: -0.0837, Episode Time: 0:00:00.202909
# Test Episode: 3500, Reward: 500.0, Mean Reward [Last 10]: 500.0000, Max Reward: 500.0, Test Time: 0:00:00.916823
# Episode: 3600, Reward: 500.0, Mean Reward [Last 100]: 497.5400, Max Reward: 500.0, Loss: -0.1531, Episode Time: 0:00:00.188185
# Test Episode: 3600, Reward: 500.0, Mean Reward [Last 10]: 500.0000, Max Reward: 500.0, Test Time: 0:00:00.762365
# Episode: 3700, Reward: 500.0, Mean Reward [Last 100]: 500.0000, Max Reward: 500.0, Loss: -0.0864, Episode Time: 0:00:00.237529
# Test Episode: 3700, Reward: 500.0, Mean Reward [Last 10]: 500.0000, Max Reward: 500.0, Test Time: 0:00:00.791661
# Episode: 3800, Reward: 500.0, Mean Reward [Last 100]: 500.0000, Max Reward: 500.0, Loss: -0.0122, Episode Time: 0:00:00.233015
# Test Episode: 3800, Reward: 500.0, Mean Reward [Last 10]: 500.0000, Max Reward: 500.0, Test Time: 0:00:00.727630
# Episode: 3900, Reward: 500.0, Mean Reward [Last 100]: 478.6900, Max Reward: 500.0, Loss: 0.0150, Episode Time: 0:00:00.208385
# Test Episode: 3900, Reward: 500.0, Mean Reward [Last 10]: 500.0000, Max Reward: 500.0, Test Time: 0:00:00.738644
# Episode: 4000, Reward: 500.0, Mean Reward [Last 100]: 500.0000, Max Reward: 500.0, Loss: 0.0225, Episode Time: 0:00:00.236091
# Test Episode: 4000, Reward: 500.0, Mean Reward [Last 10]: 500.0000, Max Reward: 500.0, Test Time: 0:00:00.785367
# Episode: 4100, Reward: 500.0, Mean Reward [Last 100]: 462.4800, Max Reward: 500.0, Loss: -0.0131, Episode Time: 0:00:00.200537
# Test Episode: 4100, Reward: 500.0, Mean Reward [Last 10]: 500.0000, Max Reward: 500.0, Test Time: 0:00:00.756892
# Episode: 4200, Reward: 500.0, Mean Reward [Last 100]: 486.2500, Max Reward: 500.0, Loss: -0.0775, Episode Time: 0:00:00.197636
# Test Episode: 4200, Reward: 500.0, Mean Reward [Last 10]: 500.0000, Max Reward: 500.0, Test Time: 0:00:00.677170
# Episode: 4300, Reward: 500.0, Mean Reward [Last 100]: 495.1400, Max Reward: 500.0, Loss: 0.1445, Episode Time: 0:00:00.187097
# Test Episode: 4300, Reward: 500.0, Mean Reward [Last 10]: 500.0000, Max Reward: 500.0, Test Time: 0:00:00.645103
# Episode: 4400, Reward: 500.0, Mean Reward [Last 100]: 461.1200, Max Reward: 500.0, Loss: 0.1502, Episode Time: 0:00:00.230069
# Test Episode: 4400, Reward: 500.0, Mean Reward [Last 10]: 500.0000, Max Reward: 500.0, Test Time: 0:00:00.760683
# Episode: 4500, Reward: 142.0, Mean Reward [Last 100]: 242.7700, Max Reward: 500.0, Loss: -0.3275, Episode Time: 0:00:00.065797
# Test Episode: 4500, Reward: 142.0, Mean Reward [Last 10]: 145.5000, Max Reward: 500.0, Test Time: 0:00:00.230333
# Episode: 4600, Reward: 228.0, Mean Reward [Last 100]: 157.2700, Max Reward: 500.0, Loss: -0.1850, Episode Time: 0:00:00.114002
# Test Episode: 4600, Reward: 228.0, Mean Reward [Last 10]: 255.6000, Max Reward: 500.0, Test Time: 0:00:00.440050
# Episode: 4700, Reward: 442.0, Mean Reward [Last 100]: 432.4400, Max Reward: 500.0, Loss: 0.0664, Episode Time: 0:00:00.181749
# Test Episode: 4700, Reward: 442.0, Mean Reward [Last 10]: 383.8000, Max Reward: 500.0, Test Time: 0:00:00.529014
# Episode: 4800, Reward: 120.0, Mean Reward [Last 100]: 167.1000, Max Reward: 500.0, Loss: -0.1124, Episode Time: 0:00:00.047143
# Test Episode: 4800, Reward: 120.0, Mean Reward [Last 10]: 121.4000, Max Reward: 500.0, Test Time: 0:00:00.189452
# Episode: 4900, Reward: 145.0, Mean Reward [Last 100]: 133.6400, Max Reward: 500.0, Loss: -0.1207, Episode Time: 0:00:00.053738
# Test Episode: 4900, Reward: 145.0, Mean Reward [Last 10]: 148.2000, Max Reward: 500.0, Test Time: 0:00:00.239110
# Episode: 5000, Reward: 399.0, Mean Reward [Last 100]: 230.6100, Max Reward: 500.0, Loss: -0.0709, Episode Time: 0:00:00.141309
# Test Episode: 5000, Reward: 399.0, Mean Reward [Last 10]: 392.2000, Max Reward: 500.0, Test Time: 0:00:00.481355

# %%
import matplotlib.pyplot as plt

episode_rewards = agent.episode_rewards
test_episode_rewards = agent.test_episode_rewards

train_episodes = list(range(1, len(agent.episode_rewards)+1))
test_episodes = list(range(1, len(agent.test_episode_rewards)+1, 1))
test_episodes_per_test = list(range(10, len(agent.test_episode_rewards)+1, 10))

episode_rewards = np.array(episode_rewards)
test_episode_rewards = np.array(test_episode_rewards)

mean_rewards = []
mean_test_rewards_per_test = []
mean_test_rewards_l100 = []
for i in range(len(episode_rewards)):
    mean_rewards.append(episode_rewards[max(0, i-100):i+1].mean())
for i in range(len(test_episode_rewards)):
    if (i+1) % config.num_test_episodes == 0:
        mean_test_rewards_per_test.append(test_episode_rewards[max(0, i-config.num_test_episodes):i+1].mean())
    mean_test_rewards_l100.append(test_episode_rewards[max(0, i-100):i+1].mean())

plt.figure(figsize=(10, 6))

idx_full_rewards = np.array(test_episode_rewards) == 500
idx_full_mean_rewards = np.array(mean_test_rewards_per_test) == 500

plt.plot(train_episodes, mean_rewards, label='Train Rewards [Last 100]')
plt.plot(test_episodes, mean_test_rewards_l100, label='Test Rewards [Last 100]')
plt.scatter(np.array(test_episodes)[idx_full_rewards], 
            np.array(test_episode_rewards)[idx_full_rewards], label='Test Rewards = 500', alpha=0.6, s=5, color = 'green')
plt.scatter(np.array(test_episodes_per_test)[idx_full_mean_rewards], 
            np.array(mean_test_rewards_per_test)[idx_full_mean_rewards], label='Test Rewards [Last 10] = 500', alpha=0.6, s=50, color = 'red')

plt.xlabel("Episode")
plt.ylabel("Reward")
plt.title("REINFORCE with baseline v2 (baseline = average of the returns in that episode)")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

episode_rewards = agent.episode_rewards[:1000]
test_episode_rewards = agent.test_episode_rewards[:1000]

train_episodes = list(range(1, len(episode_rewards)+1))
test_episodes = list(range(1, len(test_episode_rewards)+1, 1))
test_episodes_per_test = list(range(10, len(test_episode_rewards)+1, 10))

episode_rewards = np.array(episode_rewards)
test_episode_rewards = np.array(test_episode_rewards)

mean_rewards = []
mean_test_rewards_per_test = []
mean_test_rewards_l100 = []
for i in range(len(episode_rewards)):
    mean_rewards.append(episode_rewards[max(0, i-100):i+1].mean())
for i in range(len(test_episode_rewards)):
    if (i+1) % config.num_test_episodes == 0:
        mean_test_rewards_per_test.append(test_episode_rewards[max(0, i-config.num_test_episodes):i+1].mean())
    mean_test_rewards_l100.append(test_episode_rewards[max(0, i-100):i+1].mean())

plt.figure(figsize=(10, 6))

idx_full_rewards = np.array(test_episode_rewards) == 500
idx_full_mean_rewards = np.array(mean_test_rewards_per_test) == 500

plt.plot(train_episodes, mean_rewards, label='Train Rewards [Last 100]')
plt.plot(test_episodes, mean_test_rewards_l100, label='Test Rewards [Last 100]')
plt.scatter(np.array(test_episodes)[idx_full_rewards], 
            np.array(test_episode_rewards)[idx_full_rewards], label='Test Rewards = 500', alpha=0.6, s=5, color = 'green')
plt.scatter(np.array(test_episodes_per_test)[idx_full_mean_rewards], 
            np.array(mean_test_rewards_per_test)[idx_full_mean_rewards], label='Test Rewards [Last 10] = 500', alpha=0.6, s=50, color = 'red')

plt.xlabel("Episode")
plt.ylabel("Reward")
plt.title("REINFORCE with baseline")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
